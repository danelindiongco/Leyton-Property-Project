# %% [markdown]
# # Web Scraping
#
#
#
# Forming a CSV file for data from https://www.rightmove.co.uk/house-prices/e10.html?page=1 . I want to first extract the data from the first page before going ahead and scraping the other 40 pages.

# %%
import requests
import bs4

# %%
url = 'https://www.rightmove.co.uk/house-prices/e10.html?page=1'
res = requests.get(url)
res.text
# Out:
# '<!DOCTYPE html><html><head lang="en"><meta charset="utf-8"><title>House Prices in E10</title><meta name="viewport" content="width=device-width,initial-scale=1"><meta name="description" content="The average price for a property in E10 is £519,239 over the last year. Use Rightmove online house price checker tool to find out exactly how much properties sold for in E10 since 1995 (based on official Land Registry data)."><!-- Favicons --><link rel="shortcut icon" href="/spw/images/favicons/favicon.ico?v=1"><!-- APPLE ICONS --><link rel="apple-touch-icon" sizes="72x72" href="/spw/images/favicons/apple-touch-icon-72x72.png"><link rel="apple-touch-icon" sizes="114x114" href="/spw/images/favicons/apple-touch-icon-114x114.png"><link rel="apple-touch-icon" sizes="120x120" href="/spw/images/favicons/apple-touch-icon-120x120.png"><link rel="apple-touch-icon" sizes="144x144" href="/spw/images/favicons/apple-touch-icon-144x144.png"><link rel="apple-touch-icon" sizes="152x152" href="/spw/images/favicons/apple-touch-icon-152x152.png"><!-- ANDROID AND CHROME ICONS --><link rel="manifest" href="/spw/images/favicons/manifest.json"><!-- MICROSOFT ICONS --><meta name="msapplication-TileColor" content=""><meta name="msapplication-TileImage" content="/spw/images/favicons/mstile-144x144.png"><meta name="msapplication-config" content="/spw/images/favicons/browserconfig.xml"><meta name="apple-mobile-web-app-title" content="Rightmove"><meta name="application-name" content="Rightmove"><meta name="theme-color" content=""><link rel="canonical" href="https://www.rightmove.co.uk/house-prices/e10.html">  <style>@font-face {\n            font-family: \'Effra\';\n            src: url(\'/ps/fonts/effra/Effra_WLatn_Md.eot\'); /* IE9 Compat Modes */\n            src: /* IE6-IE8 */ url(\'/ps/fonts/effra/Effra_WLatn_Md.eot?#iefix\') format(\'embedded-opentype\'),\n                /* Super Modern Browsers */ url(\'/ps/fonts/effra/Effra_WLatn_Md.woff2\') format(\'woff2\'),\n                /* Pretty Modern Browsers */ url(\'/ps/fonts/effra/Effra_WLatn_Md.woff\') format(\'woff\');\n            font-style: normal;\n            font-weight: 500;\n        }\n\n        @font-face {\n            font-family: \'Effra\';\n            src: url(\'/ps/fonts/effra/Effra_WLatn_Rg.eot\');\n            src: /* IE6-IE8 */ url(\'/ps/fonts/effra/Effra_WLatn_Rg.eot?#iefix\') format(\'embedded-opentype\'),\n                /* Super Modern Browsers */ url(\'/ps/fonts/effra/Effra_WLatn_Rg.woff2\') format(\'woff\'),\n                /* Pretty Modern Browsers */ url(\'/ps/fonts/effra/Effra_WLatn_Rg.woff\') format(\'woff\');\n            font-style: normal;\n            font-weight: normal;\n        }</style><meta name="mobile-web-app-capable" content="yes"><meta name="theme-color" content="#fff"><meta name="application-name" content="Webpack App"><link rel="apple-touch-icon" sizes="57x57" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-57x57.png"><link rel="apple-touch-icon" sizes="60x60" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-60x60.png"><link rel="apple-touch-icon" sizes="72x72" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-72x72.png"><link rel="apple-touch-icon" sizes="76x76" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-76x76.png"><link rel="apple-touch-icon" sizes="114x114" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-114x114.png"><link rel="apple-touch-icon" sizes="120x120" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-120x120.png"><link rel="apple-touch-icon" sizes="144x144" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-144x144.png"><link rel="apple-touch-icon" sizes="152x152" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-152x152.png"><link rel="apple-touch-icon" sizes="180x180" href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-180x180.png"><meta name="apple-mobile-web-app-capable" content="yes"><m ...

# %%
soup = bs4.BeautifulSoup(res.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html><head lang="en"><meta charset="utf-8"/><title>House Prices in E10</title><meta content="width=device-width,initial-scale=1" name="viewport"/><meta content="The average price for a property in E10 is £519,239 over the last year. Use Rightmove online house price checker tool to find out exactly how much properties sold for in E10 since 1995 (based on official Land Registry data)." name="description"/><!-- Favicons --><link href="/spw/images/favicons/favicon.ico?v=1" rel="shortcut icon"/><!-- APPLE ICONS --><link href="/spw/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/spw/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/spw/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/spw/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/spw/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><!-- ANDROID AND CHROME ICONS --><link href="/spw/images/favicons/manifest.json" rel="manifest"/><!-- MICROSOFT ICONS --><meta content="" name="msapplication-TileColor"/><meta content="/spw/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/><meta content="/spw/images/favicons/browserconfig.xml" name="msapplication-config"/><meta content="Rightmove" name="apple-mobile-web-app-title"/><meta content="Rightmove" name="application-name"/><meta content="" name="theme-color"/><link href="https://www.rightmove.co.uk/house-prices/e10.html" rel="canonical"/> <style>@font-face {
#             font-family: 'Effra';
#             src: url('/ps/fonts/effra/Effra_WLatn_Md.eot'); /* IE9 Compat Modes */
#             src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Md.eot?#iefix') format('embedded-opentype'),
#                 /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff2') format('woff2'),
#                 /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff') format('woff');
#             font-style: normal;
#             font-weight: 500;
#         }
#
#         @font-face {
#             font-family: 'Effra';
#             src: url('/ps/fonts/effra/Effra_WLatn_Rg.eot');
#             src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Rg.eot?#iefix') format('embedded-opentype'),
#                 /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff2') format('woff'),
#                 /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff') format('woff');
#             font-style: normal;
#             font-weight: normal;
#         }</style><meta content="yes" name="mobile-web-app-capable"/><meta content="#fff" name="theme-color"/><meta content="Webpack App" name="application-name"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/><meta content="yes" name="apple-mobile-web-app-capable"/><meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/><meta content="Webpack App" name="apple-mobile-web-app-title"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/favicon.ico" rel="shortcut icon"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-320x460.png" media="(device-width: 320px) and (device-height: 480px) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-640x920.png" media="(device-width: 320px) and (device-height: 480px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-640x1096.png" media="(device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-750x1294.png" media="(device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-1182x2208.png" media="(device-width: 414px) and (device-height: 736px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 3)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-1242x2148.png" media="(device-width: 414px) and (device-height: 736px) and (orientation: portrait) and (-webkit-device-pixel-ratio: 3)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-748x1024.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-768x1004.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: portrait) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-1496x2048.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/><link href="/spw/icons-f2d9ddf83977d15a0ba4c123ad ...
#                 body {
#                     margin-top: 0 !important;
#                 }
#             }</style><div class="main-content" id="content"><div class="main"><!-- PEBBLE_RENDER --></div></div><esi:include src="http://seo.preferred.h2.prod.rightmove.com/global/consumer-footer"></esi:include><style>#content {
#                 min-height: 100vh;
#                 background-color: #FFFFFF;
#             }</style><script>window.onload = function () {
#                 document.getElementById('content').style.minHeight = 'unset'
#             }</script><script>window.__PRELOADED_STATE__ = {"results":{"title":"House Prices in E10","metaTagDescription":"The average price for a property in E10 is £519,239 over the last year. Use Rightmove online house price checker tool to find out exactly how much properties sold for in E10 since 1995 (based on official Land Registry data).","containsScotland":false,"resultCount":"7,979","properties":[{"address":"11, Whitney Road, London, Greater London E10 7HG","propertyType":"Terraced","bedrooms":3,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/66k/65394/109597502/65394_whitneyrd_IMG_00_0000_max_135x100.jpeg","count":71},"hasFloorPlan":true,"transactions":[{"displayPrice":"£720,050","dateSold":"17 Dec 2021","tenure":"Freehold","newBuild":false},{"displayPrice":"£445,000","dateSold":"12 Aug 2015","tenure":"Freehold","newBuild":false}],"location":{"lat":51.57167,"lng":-0.01677},"detailUrl":"https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109597502&sale=14270152&country=england"},{"address":"82, Manor Road, Leyton, London, Greater London E10 7HN","propertyType":"Terraced","bedrooms":4,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/71k/70202/113322182/70202_102565007736_IMG_00_0000_max_135x100.jpeg","count":13},"hasFloorPlan":true,"transactions":[{"displayPrice":"£643,756","dateSold":"9 Dec 2021","tenure":"Freehold","newBuild":false},{"displayPrice":"£355,000","dateSold":"7 Sep 2007","tenure":"Freehold","newBuild":false},{"displayPrice":"£220,000","dateSold":"23 Mar 2006","tenure":"Freehold","newBuild":false}],"location":{"lat":51.57082,"lng":-0.01955},"detailUrl":"https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=113322182&sale=14270155&country=england"},{"address":"118, Newport Road, London, Greater London E10 6PG","propertyType":"Flat","bedrooms":2,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/33k/32706/111706949/32706_S76549_IMG_00_0000_max_135x100.jpeg","count":11},"hasFloorPlan":true,"transactions":[{"displayPrice":"£504,000","dateSold":"29 Nov 2021","tenure":"Leasehold","newBuild":false},{"displayPrice":"£400,000","dateSold":"7 Apr 2017","tenure":"Leasehold","newBuild":false}],"location":{"lat":51.56547,"lng":-0.00145},"detailUrl":"https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=111706949&sale=14270110&country=england"},{"address":"8, Holden House, 616, High Road Leyton, London, Greater London E10 6EZ","propertyType":"Flat","bedrooms":null,"images":{"imageUrl":"/spw/images/placeholder/no-image.svg","count":0},"hasFloorPlan":false,"transactions":[{"displayPrice":"£130,000","dateSold":"26 Nov 2021","tenure":"Leasehold","newBuild":false}],"location":{"lat":51.56901,"lng":-0.00823},"detailUrl":""},{"address":"3, Buckingham Road, London, Greater London E10 5NG","propertyType":"Terraced","bedrooms":3,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/7k/6944/119899781/6944_2766_ALEN_IMG_00_0000_max_135x100.jpeg","count":18},"hasFloorPlan":true,"transactions":[{"displayPrice":"£714,000","dateSold":"18 Nov 2021","tenure":"Freehold","newBuild":false},{"displayPrice":"£587,500","dateSold":"1 Jul 2014","tenure":"Freehold","newBuild":false},{"displayPrice":"£294,950","dateSold":"11 Aug 2006","tenure":"Freehold","newBuild":false},{"displayPrice":"£215,000","dateSold":"26 Sep 2003","tenure":"Freehold","newBuild":false},{"displayPrice":"£134,995","dateSold":"10 Dec 1999","tenure":"Freehold","newBuild":false}],"location":{"lat":51.56015,"lng":-0.01063},"detailUrl":"https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=119899781&sale=14270071&country=england"},{"address":"55, Francis Road, London, Greater London E10 6PN","propertyType":"Flat","bedrooms":3,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/77k/76750/47818463/76750_3bedff_IMG_00_0000_max_135x100.jpg","count":4},"hasFloorPlan":false,"transactions":[{"displayPrice":"£540,000","dateSold":"15 Nov 2021","tenure":"Leasehold","newBuild":false},{"displayPrice":"£440,000","date ...

# %%
soup.select('.main')[0]
# Out:
# <div class="main"><!-- PEBBLE_RENDER --></div>

# %%
soup.title.text
# Out:
# 'House Prices in E10'

# %%
soup.title
# Out:
# <title>House Prices in E10</title>

# %%
soup.find_all('div')[1]
# Out:
# <div class="main-content" id="content"><div class="main"><!-- PEBBLE_RENDER --></div></div>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head lang="en">
#   <meta charset="utf-8"/>
#   <title>
#    House Prices in E10
#   </title>
#   <meta content="width=device-width,initial-scale=1" name="viewport"/>
#   <meta content="The average price for a property in E10 is £519,239 over the last year. Use Rightmove online house price checker tool to find out exactly how much properties sold for in E10 since 1995 (based on official Land Registry data)." name="description"/>
#   <!-- Favicons -->
#   <link href="/spw/images/favicons/favicon.ico?v=1" rel="shortcut icon"/>
#   <!-- APPLE ICONS -->
#   <link href="/spw/images/favicons/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/spw/images/favicons/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/spw/images/favicons/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/spw/images/favicons/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/spw/images/favicons/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <!-- ANDROID AND CHROME ICONS -->
#   <link href="/spw/images/favicons/manifest.json" rel="manifest"/>
#   <!-- MICROSOFT ICONS -->
#   <meta content="" name="msapplication-TileColor"/>
#   <meta content="/spw/images/favicons/mstile-144x144.png" name="msapplication-TileImage"/>
#   <meta content="/spw/images/favicons/browserconfig.xml" name="msapplication-config"/>
#   <meta content="Rightmove" name="apple-mobile-web-app-title"/>
#   <meta content="Rightmove" name="application-name"/>
#   <meta content="" name="theme-color"/>
#   <link href="https://www.rightmove.co.uk/house-prices/e10.html" rel="canonical"/>
#   <style>
#    @font-face {
#             font-family: 'Effra';
#             src: url('/ps/fonts/effra/Effra_WLatn_Md.eot'); /* IE9 Compat Modes */
#             src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Md.eot?#iefix') format('embedded-opentype'),
#                 /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff2') format('woff2'),
#                 /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Md.woff') format('woff');
#             font-style: normal;
#             font-weight: 500;
#         }
#
#         @font-face {
#             font-family: 'Effra';
#             src: url('/ps/fonts/effra/Effra_WLatn_Rg.eot');
#             src: /* IE6-IE8 */ url('/ps/fonts/effra/Effra_WLatn_Rg.eot?#iefix') format('embedded-opentype'),
#                 /* Super Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff2') format('woff'),
#                 /* Pretty Modern Browsers */ url('/ps/fonts/effra/Effra_WLatn_Rg.woff') format('woff');
#             font-style: normal;
#             font-weight: normal;
#         }
#   </style>
#   <meta content="yes" name="mobile-web-app-capable"/>
#   <meta content="#fff" name="theme-color"/>
#   <meta content="Webpack App" name="application-name"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-icon-180x180.png" rel="apple-touch-icon" sizes="180x180"/>
#   <meta content="yes" name="apple-mobile-web-app-capable"/>
#   <meta content="black-translucent" name="apple-mobile-web-app-status-bar-style"/>
#   <meta content="Webpack App" name="apple-mobile-web-app-title"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/favicon-16x16.png" rel="icon" sizes="16x16" type="image/png"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/favicon.ico" rel="shortcut icon"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-320x460.png" media="(device-width: 320px) and (device-height: 480px) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-640x920.png" media="(device-width: 320px) and (device-height: 480px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-640x1096.png" media="(device-width: 320px) and (device-height: 568px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-750x1294.png" media="(device-width: 375px) and (device-height: 667px) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-1182x2208.png" media="(device-width: 414px) and (device-height: 736px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 3)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-1242x2148.png" media="(device-width: 414px) and (device-height: 736px) and (orientation: portrait) and (-webkit-device-pixel-ratio: 3)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-748x1024.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-768x1004.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: portrait) and (-webkit-device-pixel-ratio: 1)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-1496x2048.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: landscape) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#   <link href="/spw/icons-f2d9ddf83977d15a0ba4c123adf6e0da/apple-touch-startup-image-1536x2008.png" media="(device-width: 768px) and (device-height: 1024px) and (orientation: portrait) and (-webkit-device-pixel-ratio: 2)" rel="apple-touch-startup-image"/>
#   <link href="/spw/css/vendors~soldPrices.42f6b196a195bb7dd586.css" rel="stylesheet"/>
#   <link href="/spw/css/soldPrices.c78dfb8b6effb70534e2.css" rel="stylesheet"/>
#  </head>
#  <body>
#   <div class="svg-sprite" style="height: 0; width: 0; overflow: hidden;">
#    <svg height="0" style="position:absolute" width="0">
#     <symbol id="account-silhouette" viewbox="0 0 13.8 21.8">
#      <circle cx="6.9" cy="5" r="5">
#      </circle>
#      <path d="M12 13.6L8.7 12c-.5-.2-1.2-.4-1.8-.4s-1.3.2-1.8.4l-3.3 1.6c-1 .5-1.8 1.8-1.8 2.9v3.3c0 1.1.9 2 2 2h9.8c1.1 0 2-.9 2-2v-3.3c0-1.1-.8-2.4-1.8-2.9z">
#      </path>
#     </symbol>
#     <symbol id="camera" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M6 4h5a3 3 0 013 3v5a2 2 0 01-2 2H4a2 2 0 01-2-2V7c0-1.306.835-2.417 2-2.83V3h2v1zM3 7v5a1 1 0 001 1h8a1 1 0 001-1V7a2 2 0 00-2-2H5a2 2 0 00-2 2zm5 4.25a2.25 2.25 0 110-4.5 2.25 2.25 0 010 4.5zm0-1a1.25 1.25 0 110-2.5 1.25 1.25 0 010 2.5zM4.5 7a.5.5 0 110-1 .5.5 0 010 1z" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="floorplan" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M13 8v4a1 1 0 01-1 1H7v1h5a2 2 0 002-2V4a2 2 0 00-2-2H4a2 2 0 00-2 2v8a2 2 0 002 2h1v-1H4a1 1 0 01-1-1v-1h6v-1H3V4a1 1 0 011-1h1v4h1V3h6a1 1 0 011 1v3H9v1h4z">
#      </path>
#     </symbol>
#     <symbol id="hmlr" preserveaspectratio="xMinYMin meet" viewbox="0 0 197.53 72.83" xmlns="http://www.w3.org/2000/svg">
#      <defs>
#       <style>
#        .dcls-1{fill:#b2b2b2}.dcls-2{fill:#76b82a}.dcls-3{fill:#bccf00}.dcls-4{fill:#f2e500}
#       </style>
#      </defs>
#      <path class="dcls-1" d="M139.06 21.99l-2.73-4.73 2.73-4.72h5.46l2.73 4.72-2.73 4.73h-5.46zM130.88 36.17l-2.73-4.73 2.73-4.73h5.45l2.73 4.73-2.73 4.73h-5.45zM171.8 21.99l-2.73-4.73 2.73-4.72h5.46l2.73 4.72-2.73 4.73h-5.46zM179.99 36.16l-2.73-4.72 2.73-4.73h5.46l2.72 4.73-2.73 4.72h-5.45zM147.25 64.52l-2.73-4.72 2.73-4.73h5.45l2.73 4.73-2.73 4.72h-5.45zM163.62 64.52l-2.73-4.72 2.73-4.73h5.45l2.73 4.73-2.73 4.72h-5.45zM155.43 31.44l-2.73-4.73 2.73-4.72h5.46l2.73 4.72
54c0-1-.47-1.42-1.77-1.54l-5.33-.53c-2.28-.24-3.11-1.51-3.11-3v-1.6a2.21 2.21 0 01.8-2l1.18-.92a3.4 3.4 0 012-.56h7.43v1.86h-6.97a2 2 0 00-1.33.36l-.51.38a1.46 1.46 0 00-.53 1.07v.92c0 .91.48 1.36 1.72 1.48l5 .5c2.55.27 3.46 1.36 3.46 3v1.95a2.17 2.17 0 01-.77 1.94zM79.72 58.8a3.28 3.28 0 01-2.27-.69l-1.22-1.06a2.65 2.65 0 01-1-2.43V40.53h2.19v3.26H82v1.86h-4.61v8.76a2 2 0 00.85 1.6l.36.3a2.46 2.46 0 002 .62H82v1.87zM86.9 45.65V58.8h-2.19V45l1.12-1.21h6.45v1.86zM105.88 63.14l-1.25 1.1a3.18 3.18 0 01-2.22.77h-6.57v-1.87h5.72a2.4 2.4 0 001.89-.71L104 62a1.74 1.74 0 00.77-1.39V58.8h-4.84a3 3 0 01-2.25-.8l-1.9-1.71a2.2 2.2 0 01-.78-1.82V43.79h2.19v9.56a2.64 2.64 0 001.07 2.19l.62.56a2.87 2.87 0 002.16.83h3.79V43.79H107v17a2.6 2.6 0 01-1.12 2.35z">
#      </path>
#     </symbol>
#     <symbol id="houses" viewbox="0 0 71 59" xmlns="http://www.w3.org/2000/svg">
#      <path d="M35.481 13.351l21.557 19.641c.414.39.65.94.65 1.516V56.5c0 1.14-.904 2.063-2.018 2.063H15.33c-1.114 0-2.018-.924-2.018-2.063V34.507c0-.575.235-1.124.649-1.515l21.52-19.64zm.003 6.006L17.75 35.542v18.583h35.5v-18.58L35.484 19.356zM22.187.902l10.047 9.257-3.27 3.022-6.777-6.243-17.75 16.36v17.515l4.438-.009v4.438l-6.656.008A2.219 2.219 0 010 43.031V22.326c0-.618.258-1.209.713-1.629L22.188.902zM48.813.897l21.473 19.8c.456.42.715 1.011.715 1.63v20.704a2.219 2.219 0 01-2.219 2.219l-6.656-.004v-4.438l4.438.005V23.3L48.813 6.933l-6.799 6.265-3.27-3.018L48.813.897z" fill="#A1A1AC" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="icon-arrow" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M13.293 8H2v1h11l-4 4 .707.707 5.354-5.353L9.707 3 9 3.707z">
#      </path>
#     </symbol>
#     <symbol id="icon-chevron-down" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M3 6h10l-5 6z">
#      </path>
#     </symbol>
#     <symbol id="icon-close" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M8 8H2v1h6v6h1V9h6V8H9V2H8z">
#      </path>
#     </symbol>
#     <symbol id="icon-graph-arrow-down" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M8.97 9.677L6.646 12H12V6.646L9.677 8.97 4.354 3.646l-.708.708z">
#      </path>
#     </symbol>
#     <symbol id="icon-graph-arrow-up" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M9.354 7.354L12 10V4H6l2.646 2.646-5 5 .708.708z">
#      </path>
#     </symbol>
#     <symbol id="icon-minus" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M2 8v1h13V8z">
#      </path>
#     </symbol>
#     <symbol id="icon-plus" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <path d="M8 8H2v1h6v6h1V9h6V8H9V2H8z">
#      </path>
#     </symbol>
#     <symbol id="mortgage-arrow" viewbox="0 0 8 12" xmlns="http://www.w3.org/2000/svg">
#      <path d="M4 0l4 6.001H5.334V12H2.668V6.001H0z" fill="#53535F" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="mortgage-house" viewbox="0 0 53 53" xmlns="http://www.w3.org/2000/svg">
#      <path d="M26.5 0l26.1 19.575a1 1 0 01.4.8V51a2 2 0 01-2 2H2a2 2 0 01-2-2V20.375a1 1 0 01.4-.8L26.5 0zm0 4.14L3.312 21.532v27.157a1 1 0 001 1h44.376a1 1 0 001-1V21.53L26.5 4.141zm.954 12.422c.954 0 1.802.113 2.544.338a9.71 9.71 0 011.928.795 7.72 7.72 0 011.351.934c.358.319.643.57.855.756l-2.305 2.544a9.368 9.368 0 00-1.69-1.391c-.65-.425-1.543-.637-2.683-.637-.795 0-1.464.153-2.007.458a3.554 3.554 0 00-1.292 1.212 5.126 5.126 0 00-.676 1.749 10.73 10.73 0 00-.199 2.107v2.464h7.95v3.021h-7.95v7.99h11.488v3.419H19.464V30.912h-2.901v-3.02h2.901v-3.22c0-.716.1-1.544.298-2.485a7.408 7.408 0 011.153-2.663c.57-.835 1.378-1.537 2.425-2.107 1.047-.57 2.418-.855 4.114-.855z" fill="#E9E9EB" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="mortgage-house-alt" viewbox="0 0 53 53" xmlns="http://www.w3.org/2000/svg">
#      <path d="M26.5 0l26.1 19.575a1 1 0 01.4.8V51a2 2 0 01-2 2H2a2 2 0 01-2-2V20.375a1 1 0 01.4-.8L26.5 0zm0 4.14L3.312 21.532v27.157a1 1 0 001 1h44.376a1 1 0 001-1V21.53L26.5 4.141zm.954 12.422c.954 0 1.802.113 2.544.338a9.71 9.71 0 011.928.795 7.72 7.72 0 011.351.934c.358.319.643.57.855.756l-2.305 2.544a9.368 9.368 0 00-1.69-1.391c-.65-.425-1.543-.637-2.683-.637-.795 0-1.464.153-2.007.458a3.554 3.554 0 00-1.292 1.212 5.126 5.126 0 00-.676 1.749 10.73 10.73 0 00-.199 2.107v2.464h7.95v3.021h-7.95v7.99h11.488v3.419H19.464V30.912h-2.901v-3.02h2.901v-3.22c0-.716.1-1.544.298-2.485a7.408 7.408 0 011.153-2.663c.57-.835 1.378-1.537 2.425-2.107 1.047-.57 2.418-.855 4.114-.855z" fill="#262637" fill-rule="evenodd">
#      </path>
#     </symbol>
#     <symbol id="open-chevron-down" style="background:#fff" viewbox="0 0 16 16" xmlns="http://www.w3.org/2000/svg">
#      <g fill="none" fill-rule="evenodd">
#       <path d="M0 0h16v16H0z" fill="#FFF" opacity=".01">
#       </path>
#       <path d="M8 10.293l5.146-5.147a.5.5 0 01.708.708l-5.5 5.5a.5.5 0 01-.708 0l-5.5-5.5a.5.5 0 11.708-.708L8 10.293z" fill="#262637">
#       </path>
#      </g>
#     </symbol>
#     <symbol clip-rule="evenodd" fill-rule="evenodd" id="rightmove-icon-logo" stroke-linejoin="round" stroke-miterlimit="1.414" viewbox="0 0 2099 2138" xmlns="http://www.w3.org/2000/svg">
 0-2-6.69-.78-6.69-5.77 0-2.74 2.35-4.42 5.41-4.42a7.05 7.05 0 014.28 1.31c.26.18.21.39-.31 1.28l-.23.37c-.47.81-.65.94-.94.76a4.81 4.81 0 00-2.67-.84 2.69 2.69 0 00-1.7.45 1 1 0 00-.37.76c0 2 6.69.94 6.69 5.65a4.42 4.42 0 01-1.33 3.16 6 6 0 01-4.31 1.44 7.66 7.66 0 01-4.83-1.59c-.21-.18-.18-.42.23-1.18l.26-.47-.02.01zm-87.28 23.76c0 4.73-2.35 7.42-6.72 7.42-3.89 0-6.27-2.38-6.27-6.9 0-4.73 2.35-7.42 6.72-7.42 3.91-.01 6.29 2.37 6.29 6.89l-.02.01zm-9.3.37c0 2.53.84 4 2.67 4 2.07 0 3-1.57 3-4.18 0-2.61-.84-4-2.66-4-2.1-.01-2.99 1.56-2.99 4.17l-.02.01zm12.86-7v-.63a6 6 0 011.46-4.34 5 5 0 013.76-1.36 8.77 8.77 0 012.88.5c.23.08.26.29.05 1.2l-.1.44c-.21.92-.34 1.07-.55 1a7.69 7.69 0 00-1.67-.21 2 2 0 00-1.75.68 3.75 3.75 0 00-.5 2.17v.52h3c.24 0 .34.05.34 1.31v.18c0 1.25-.1 1.31-.34 1.31h-3v10.61c0 .29-.16.39-1.7.39h-.13c-1.7 0-1.75-.1-1.75-.39v-10.6h-1.83c-.23 0-.34-.05-.34-1.31v-.2c0-1.25.1-1.31.34-1.31l1.83.04zm26.16-1.91c-.47 1-.63 1-.94.81a5.82 5.82 0 00-3.24-1.1 2.19 2.19 0 00-2.46 2.12c0 1.33 1.44 2 2.93 2.74 2.25 1.15 4.73 2.43 4.73 5.72 0 3.29-2.14 5.67-6.35 5.67a9.22 9.22 0 01-5.58-1.78c-.3 ...
#       </path>
#      </g>
#     </symbol>
#    </svg>
#   </div>
#   <esi:include src="http://seo.preferred.h2.prod.rightmove.com/global/consumer-nav">
#   </esi:include>
#   <style>
#    @media (min-width: 1024px) {
#                 body {
#                     margin-top: 0 !important;
#                 }
#             }
#   </style>
#   <div class="main-content" id="content">
#    <div class="main">
#     <!-- PEBBLE_RENDER -->
#    </div>
#   </div>
#   <esi:include src="http://seo.preferred.h2.prod.rightmove.com/global/consumer-footer">
#   </esi:include>
#   <style>
#    #content {
#                 min-height: 100vh;
#                 background-color: #FFFFFF;
#             }
#   </style>
#   <script>
#    window.onload = function () {
#                 document.getElementById('content').style.minHeight = 'unset'
#             }
#   </script>
#   <script>
#    window.__PRELOADED_STATE__ = {"results":{"title":"House Prices in E10","metaTagDescription":"The average price for a property in E10 is £519,239 over the last year. Use Rightmove online house price checker tool to find out exactly how much properties sold for in E10 since 1995 (based on official Land Registry data).","containsScotland":false,"resultCount":"7,979","properties":[{"address":"11, Whitney Road, London, Greater London E10 7HG","propertyType":"Terraced","bedrooms":3,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/66k/65394/109597502/65394_whitneyrd_IMG_00_0000_max_135x100.jpeg","count":71},"hasFloorPlan":true,"transactions":[{"displayPrice":"£720,050","dateSold":"17 Dec 2021","tenure":"Freehold","newBuild":false},{"displayPrice":"£445,000","dateSold":"12 Aug 2015","tenure":"Freehold","newBuild":false}],"location":{"lat":51.57167,"lng":-0.01677},"detailUrl":"https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109597502&sale=14270152&country=england"},{"address":"82, Manor Road, Leyton, London, Greater London E10 7HN","propertyType":"Terraced","bedrooms":4,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/71k/70202/113322182/70202_102565007736_IMG_00_0000_max_135x100.jpeg","count":13},"hasFloorPlan":true,"transactions":[{"displayPrice":"£643,756","dateSold":"9 Dec 2021","tenure":"Freehold","newBuild":false},{"displayPrice":"£355,000","dateSold":"7 Sep 2007","tenure":"Freehold","newBuild":false},{"displayPrice":"£220,000","dateSold":"23 Mar 2006","tenure":"Freehold","newBuild":false}],"location":{"lat":51.57082,"lng":-0.01955},"detailUrl":"https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=113322182&sale=14270155&country=england"},{"address":"118, Newport Road, London, Greater London E10 6PG","propertyType":"Flat","bedrooms":2,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/33k/32706/111706949/32706_S76549_IMG_00_0000_max_135x100.jpeg","count":11},"hasFloorPlan":true,"transactions":[{"displayPrice":"£504,000","dateSold":"29 Nov 2021","tenure":"Leasehold","newBuild":false},{"displayPrice":"£400,000","dateSold":"7 Apr 2017","tenure":"Leasehold","newBuild":false}],"location":{"lat":51.56547,"lng":-0.00145},"detailUrl":"https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=111706949&sale=14270110&country=england"},{"address":"8, Holden House, 616, High Road Leyton, London, Greater London E10 6EZ","propertyType":"Flat","bedrooms":null,"images":{"imageUrl":"/spw/images/placeholder/no-image.svg","count":0},"hasFloorPlan":false,"transactions":[{"displayPrice":"£130,000","dateSold":"26 Nov 2021","tenure":"Leasehold","newBuild":false}],"location":{"lat":51.56901,"lng":-0.00823},"detailUrl":""},{"address":"3, Buckingham Road, London, Greater London E10 5NG","propertyType":"Terraced","bedrooms":3,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/7k/6944/119899781/6944_2766_ALEN_IMG_00_0000_max_135x100.jpeg","count":18},"hasFloorPlan":true,"transactions":[{"displayPrice":"£714,000","dateSold":"18 Nov 2021","tenure":"Freehold","newBuild":false},{"displayPrice":"£587,500","dateSold":"1 Jul 2014","tenure":"Freehold","newBuild":false},{"displayPrice":"£294,950","dateSold":"11 Aug 2006","tenure":"Freehold","newBuild":false},{"displayPrice":"£215,000","dateSold":"26 Sep 2003","tenure":"Freehold","newBuild":false},{"displayPrice":"£134,995","dateSold":"10 Dec 1999","tenure":"Freehold","newBuild":false}],"location":{"lat":51.56015,"lng":-0.01063},"detailUrl":"https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=119899781&sale=14270071&country=england"},{"address":"55, Francis Road, London, Greater London E10 6PN","propertyType":"Flat","bedrooms":3,"images":{"imageUrl":"https://media.rightmove.co.uk/dir/77k/76750/47818463/76750_3bedff_IMG_00_0000_max_135x100.jpg","count":4},"hasFloorPlan":false,"transactions":[{"displayPrice":"£540,000","dateSold":"15 Nov 2021","tenure":"Leasehold","newBuild":false},{"displayPrice":"£440,000","dateSold":"5 Aug 2016","tenure" ...
#   </script>
#   <script>
#    window.__APP_CONFIG__ = {"buildVersion":"2.2.0.1642521055","staticFilesUrl":"","partialsContentHost":"http://seo.preferred.h2.prod.rightmove.com","gtmId":"GTM-M5C7HFR","gtmUaCode":"UA-3350334-63","typeaheadModel":{"url":"https://www.rightmove.co.uk/typeAhead/ukstreet/"},"addressPickerModel":{"url":"https://www.rightmove.co.uk/ajax/address"},"serverTimeStamp":1645457994798,"deviceType":"desktop","mvtInfo":[{"label":"SPWSwitches.GOOGLE_OPTIMIZE_ENABLED","state":"off","shouldLog":false},{"label":"SPWSwitches.USE_RM_ASSISTANT","state":"on","shouldLog":false},{"label":"SPWSwitches.GOOGLE_OPTIMIZE_PAGE_HIDING_ENABLED","state":"off","shouldLog":false},{"label":"PSEServiceSwitches.MATCH_ON_ADDRESS_ID","state":"off","shouldLog":false},{"label":"CookieBarSwitches.BLOCK_UNKNOWN_COOKIES","state":"off","shouldLog":false},{"label":"CookieBarSwitches.ENABLE_ONE_TRUST_COOKIE_SCRIPT","state":"on","shouldLog":true},{"label":"SPWSwitches.USE_RM_DATALAYER","state":"on","shouldLog":false}],"user":null,"viewType":{"partial":false,"error":false},"mrmUrl":"//my.rightmove.co.uk","mediaServerUrl":"https://media.rightmove.co.uk","recaptchaEnabled":true,"recaptchaKey":"6LeZmXUUAAAAACr8BTPYPeJhRTJzH1UCv7d5O7_X","loggedIn":false}
#   </script>
#   <script src="/spw/javascript/vendors~soldPrices.42f6b196a195bb7dd586.bundle.js" type="text/javascript">
#   </script>
#   <script src="/spw/javascript/soldPrices.c78dfb8b6effb70534e2.bundle.js" type="text/javascript">
#   </script>
#  </body>
# </html>

# %%
from subprocess import check_output
import json

s = soup.select('script')
s = s[1]
js = 'window = {};\n'+s.text.strip()+';\nprocess.stdout.write(JSON.stringify(window.__PRELOADED_STATE__));'
with open('temp.js','w') as f:
    f.write(js)
window_init_state = check_output(['node','temp.js'])
big_file = json.loads(window_init_state.decode("utf-8"))
big_file
# Out:
# {'results': {'title': 'House Prices in E10',
#   'metaTagDescription': 'The average price for a property in E10 is £519,239 over the last year. Use Rightmove online house price checker tool to find out exactly how much properties sold for in E10 since 1995 (based on official Land Registry data).',
#   'containsScotland': False,
#   'resultCount': '7,979',
#   'properties': [{'address': '11, Whitney Road, London, Greater London E10 7HG',
#     'propertyType': 'Terraced',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/66k/65394/109597502/65394_whitneyrd_IMG_00_0000_max_135x100.jpeg',
#      'count': 71},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£720,050',
#       'dateSold': '17 Dec 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£445,000',
#       'dateSold': '12 Aug 2015',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.57167, 'lng': -0.01677},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109597502&sale=14270152&country=england'},
#    {'address': '82, Manor Road, Leyton, London, Greater London E10 7HN',
#     'propertyType': 'Terraced',
#     'bedrooms': 4,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/71k/70202/113322182/70202_102565007736_IMG_00_0000_max_135x100.jpeg',
#      'count': 13},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£643,756',
#       'dateSold': '9 Dec 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£355,000',
#       'dateSold': '7 Sep 2007',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£220,000',
#       'dateSold': '23 Mar 2006',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.57082, 'lng': -0.01955},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=113322182&sale=14270155&country=england'},
#    {'address': '118, Newport Road, London, Greater London E10 6PG',
#     'propertyType': 'Flat',
#     'bedrooms': 2,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/33k/32706/111706949/32706_S76549_IMG_00_0000_max_135x100.jpeg',
#      'count': 11},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£504,000',
#       'dateSold': '29 Nov 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£400,000',
#       'dateSold': '7 Apr 2017',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56547, 'lng': -0.00145},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=111706949&sale=14270110&country=england'},
#    {'address': '8, Holden House, 616, High Road Leyton, London, Greater London E10 6EZ',
#     'propertyType': 'Flat',
#     'bedrooms': None,
#     'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#     'hasFloorPlan': False,
#     'transactions': [{'displayPrice': '£130,000',
#       'dateSold': '26 Nov 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56901, 'lng': -0.00823},
#     'detailUrl': ''},
#    {'address': '3, Buckingham Road, London, Greater London E10 5NG',
#     'propertyType': 'Terraced',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/7k/6944/119899781/6944_2766_ALEN_IMG_00_0000_max_135x100.jpeg',
#      'count': 18},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£714,000',
#       'dateSold': '18 Nov 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£587,500',
#       'dateSold': '1 Jul 2014',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£294,950',
#       'dateSold': '11 Aug 2006',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£215,000',
#       'dateSold': '26 Sep 2003',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£134,995',
#       'dateSold': '10 Dec 1999',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56015, 'lng': -0.01063},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=119899781&sale=14270071&country=england'},
#    {'address': '55, Francis Road, London, Greater London E10 6PN',
#     'propertyType': 'Flat',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/77k/76750/47818463/76750_3bedff_IMG_00_0000_max_135x100.jpg',
#      'count': 4},
#     'hasFloorPlan': False,
#     'transactions': [{'displayPrice': '£540,000',
#       'dateSold': '15 Nov 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£440,000',
#       'dateSold': '5 Aug 2016',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56082, 'lng': -0.00252},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=47818463&sale=14270116&country=england'},
#    {'address': '88, Chesterfield Road, London, Greater London E10 6EN',
#     'propertyType': 'Terraced',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/12k/11536/79237872/11536_0172_HRT017209345_IMG_03_0002_max_135x100.jpeg',
#      'count': 22},
#     'hasFloorPlan': False,
#     'transactions': [{'displayPrice': '£630,000',
#       'dateSold': '12 Nov 2021',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.57469, 'lng': -0.00423},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=79237872&sale=14270095&country=england'},
#    {'address': '6, Albert Road, Leyton, London, Greater London E10 6NX',
#     'propertyType': 'Flat',
#     'bedrooms': 2,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/115k/114391/90155578/114391_30514277_IMG_00_0000_max_135x100.jpeg',
#      'count': 20},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£434,500',
#       'dateSold': '5 Nov 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£225,000',
#       'dateSold': '19 Feb 2008',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£173,000',
#       'dateSold': '21 Sep 2007',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56418, 'lng': -0.00454},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=90155578&sale=13908223&country=england'},
#    {'address': '29, Colchester Road, Leyton, London, Greater London E10 6HB',
#     'propertyType': 'Terraced',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/7k/6944/66592116/6944_2574_IMG_01_0000_max_135x100.jpg',
#      'count': 14},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£740,000',
#       'dateSold': '29 Oct 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£560,500',
#       'dateSold': '11 Nov 2019',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.57274, 'lng': -0.00561},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=66592116&sale=13908196&country=england'},
#    {'address': '64, Farmer Road, London, Greater London E10 5DH',
#     'propertyType': 'Terraced',
#     'bedrooms': 4,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/120k/119695/110642300/119695_30819352_IMG_00_0000_max_135x100.jpeg',
#      'count': 14},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£615,000',
#       'dateSold': '26 Oct 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£63,000',
#       'dateSold': '25 Jul 1997',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.5695, 'lng': -0.0108},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=110642300&sale=13908133&country=england'},
#    {'address': '3, East Point, 90, Church Road, Leyton, London, Greater London E10 5JP',
#     'propertyType': 'Flat',
#     'bedrooms': None,
#     'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#     'hasFloorPlan': False,
#     'transactions': [{'displayPrice': '£322,500',
#       'dateSold': '25 Oct 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56345, 'lng': -0.01453},
#     'detailUrl': ''},
#    {'address': '19, Perth Road, London, Greater London E10 7PA',
#     'propertyType': 'Terraced',
#     'bedrooms': 2,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/1k/568/77444976/568_LEY210021_IMG_15_0003_max_135x100.jpeg',
#      'count': 15},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£410,000',
#       'dateSold': '22 Oct 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.5668, 'lng': -0.0317},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=77444976&sale=14270170&country=england'},
#    {'address': '189, Dawlish Road, London, Greater London E10 6QN',
#     'propertyType': 'Flat',
#     'bedrooms': 1,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/57k/56158/109313330/56158_LEY210074_IMG_00_0000_max_135x100.jpeg',
#      'count': 12},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£400,000',
#       'dateSold': '22 Oct 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£351,500',
#       'dateSold': '15 Sep 2017',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£49,995',
#       'dateSold': '21 Aug 1997',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56213, 'lng': -0.00579},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109313330&sale=13908238&country=england'},
#    {'address': '150, Essex Road, Leyton, London, Greater London E10 6BS',
#     'propertyType': 'Flat',
#     'bedrooms': None,
#     'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#     'hasFloorPlan': False,
#     'transactions': [{'displayPrice': '£371,000',
#       'dateSold': '18 Oct 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£368,000',
#       'dateSold': '4 Nov 2016',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£211,500',
#       'dateSold': '12 Jul 2007',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£55,000',
#       'dateSold': '17 Apr 1998',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£50,000',
#       'dateSold': '6 Sep 1996',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£28,000',
#       'dateSold': '28 May 1996',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£42,000',
#       'dateSold': '18 May 1995',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.57722, 'lng': -0.00455},
#     'detailUrl': ''},
#    {'address': '126, St Marys Road, London, Greater London E10 5RF',
#     'propertyType': 'Terraced',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/33k/32706/109461365/32706_S72674_IMG_00_0000_max_135x100.jpeg',
#      'count': 13},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£690,000',
#       'dateSold': '15 Oct 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£600,000',
#       'dateSold': '20 Dec 2018',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£215,000',
#       'dateSold': '5 Mar 2007',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.5615, 'lng': -0.00552},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109461365&sale=13908151&country=england'},
#    {'address': '43, Nottingham Road, London, Greater London E10 6BP',
#     'propertyType': 'Semi-Detached',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/115k/114391/107499713/114391_30660773_IMG_00_0000_max_135x100.jpeg',
#      'count': 30},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£756,750',
#       'dateSold': '15 Oct 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£500,000',
#       'dateSold': '8 Aug 2014',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.57606, 'lng': -0.00546},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=107499713&sale=13908175&country=england'},
#    {'address': '110, Murchison Road, London, Greater London E10 6LX',
#     'propertyType': 'Flat',
#     'bedrooms': 2,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/7k/6944/108825917/6944_3112_ALEN_IMG_00_0000_max_135x100.jpeg',
#      'count': 13},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£449,400',
#       'dateSold': '12 Oct 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£196,000',
#       'dateSold': '21 Feb 2013',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£165,000',
#       'dateSold': '4 Nov 2004',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£91,000',
#       'dateSold': '26 May 2000',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56491, 'lng': -0.00538},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=108825917&sale=13908211&country=england'},
#    {'address': '83, Newport Road, London, Greater London E10 6PH',
#     'propertyType': 'Flat',
#     'bedrooms': 2,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/120k/119695/109218089/119695_30745758_IMG_00_0000_max_135x100.jpeg',
#      'count': 15},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£480,000',
#       'dateSold': '1 Oct 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£475,000',
#       'dateSold': '14 Sep 2020',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£460,102',
#       'dateSold': '25 Jul 2016',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£175,000',
#       'dateSold': '15 Aug 2012',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56407, 'lng': -0.00368},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109218089&sale=13908229&country=england'},
#    {'address': '67, Kettlebaston Road, London, Greater London E10 7PE',
#     'propertyType': 'Flat',
#     'bedrooms': 2,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/215k/214757/105763619/214757_30583874_IMG_00_0000_max_135x100.jpeg',
#      'count': 12},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£360,000',
#       'dateSold': '30 Sep 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£124,995',
#       'dateSold': '19 Sep 2002',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£58,995',
#       'dateSold': '27 May 1999',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£43,000',
#       'dateSold': '28 Feb 1995',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56705, 'lng': -0.03097},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=105763619&sale=13908298&country=england'},
#    {'address': '42, Wilmot Road, London, Greater London E10 5LU',
#     'propertyType': 'Terraced',
#     'bedrooms': 4,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/1k/568/108751715/568_LEY210138_IMG_15_0000_max_135x100.png',
#      'count': 15},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£700,000',
#       'dateSold': '30 Sep 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£249,999',
#       'dateSold': '26 Nov 2010',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£223,000',
#       'dateSold': '4 May 2005',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£184,000',
#       'dateSold': '25 Feb 2004',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£86,000',
#       'dateSold': '31 Jul 1999',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56263, 'lng': -0.01384},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=108751715&sale=13908142&country=england'},
#    {'address': '17, Essex Road, Leyton, London, Greater London E10 6HP',
#     'propertyType': 'Terraced',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/57k/56158/108584150/56158_LEY210039_IMG_00_0000_max_135x100.jpeg',
#      'count': 14},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£850,000',
#       'dateSold': '30 Sep 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£600,000',
#       'dateSold': '25 Jan 2016',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.57365, 'lng': -0.00124},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=108584150&sale=13908199&country=england'},
#    {'address': '7, Perth Road, London, Greater London E10 7PA',
#     'propertyType': 'Flat',
#     'bedrooms': 2,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/36k/35033/107979368/35033_529018747_IMG_00_0000_max_135x100.jpeg',
#      'count': 17},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£420,000',
#       'dateSold': '29 Sep 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£275,000',
#       'dateSold': '19 Sep 2014',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.5668, 'lng': -0.0317},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=107979368&sale=14270167&country=england'},
#    {'address': '17, Huxley Road, London, Greater London E10 5QT',
#     'propertyType': 'Flat',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/203k/202958/106497410/202958_1173901-1_IMG_00_0000_max_135x100.jpeg',
#      'count': 15},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£485,000',
#       'dateSold': '29 Sep 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£226,500',
#       'dateSold': '25 Apr 2008',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56083, 'lng': -0.00844},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=106497410&sale=13631158&country=england'},
#    {'address': '27, Shortlands Road, London, Greater London E10 7AH',
#     'propertyType': 'Terraced',
#     'bedrooms': 3,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/115k/114391/106280684/114391_30613989_IMG_00_0001_max_135x100.jpeg',
#      'count': 23},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£646,800',
#       'dateSold': '29 Sep 2021',
#       'tenure': 'Freehold',
#       'newBuild': False},
#      {'displayPrice': '£510,000',
#       'dateSold': '31 May 2018',
#       'tenure': 'Freehold',
#       'newBuild': False}],
#     'location': {'lat': 51.57237, 'lng': -0.01544},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=106280684&sale=13631245&country=england'},
#    {'address': '48, Perth Road, London, Greater London E10 7PB',
#     'propertyType': 'Flat',
#     'bedrooms': 2,
#     'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/152k/151079/90505420/151079_1157966-1_IMG_00_0000_max_135x100.jpeg',
#      'count': 19},
#     'hasFloorPlan': True,
#     'transactions': [{'displayPrice': '£410,000',
#       'dateSold': '29 Sep 2021',
#       'tenure': 'Leasehold',
#       'newBuild': False},
#      {'displayPrice': '£54,000',
#       'dateSold': '28 Sep 1998',
#       'tenure': 'Leasehold',
#       'newBuild': False}],
#     'location': {'lat': 51.56617, 'lng': -0.03173},
#     'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=90505420&sale=13908295&country=england'}]},
#  'sidebar': {'blurb': ['Properties in E10 had an overall average price of £519,239 over the last year.',
#    'The majority of sales in E10 during the last year were terraced properties, selling for an average price of £621,841. Flats sold for an average of £396,993, with semi-detached properties fetching £610,750.',
#    'Overall, sold prices in E10 over the last year were 11% up on the previous year and 18% up on the 2018 peak of £439,714.'],
#   'nearbyLocations': {'title': 'House prices near E10',
#    'links': [{'text': 'House prices in E17', 'url': '/house-prices/e17.html'},
#     {'text': 'House prices in IG1', 'url': '/house-prices/ig1.html'},
#     {'text': 'House prices in N16', 'url': '/house-prices/n16.html'},
#     {'text': 'House prices in N17', 'url': '/house-prices/n17.html'},
#     {'text': 'House prices in E3', 'url': '/house-prices/e3.html'},
#     {'text': 'House prices in N4', 'url': '/house-prices/n4.html'},
#     {'text': 'House prices in E15', 'url': '/house-prices/e15.html'}]},
#   'propertyValueLinks': {'title': 'What is your property worth?',
#    'links': [{'text': 'Agent Property Valuation',
#      'url': '/property-valuation.html'},
#     {'text': 'Market Trends for E10',
#      'url': '/house-prices-in-my-area/marketTrendsTotalPropertiesSoldAndAveragePrice.html?searchLocation=E10'},
#     {'text': 'Price Comparison Report', 'url': '/house-value.html'},
#     {'text': 'Estate agents in E10',
#      'url': '/estate-agents/find.html?locationIdentifier=OUTCODE^745'},
#     {'text': 'Properties for sale in E10',
#      'url': '/property-for-sale/find.html?locationIdentifier=OUTCODE^745'},
#     {'text': 'Properties to let in E10',
#      'url': '/property-to-rent/find.html?locationIdentifier=OUTCODE^745'},
#     {'text': 'Selling guide',
#      'url': '/resources/property-guides/selling-guide.html'},
#     {'text': 'Buying guide',
#      'url': '/resources/property-guides/buying-guide.html'},
#     {'text': 'House Price Index', 'url': '/news/house-price-index'}]},
#   'staticMapUrl': 'https://media.rightmove.co.uk/map/_generate?polygonLineColor=%232E8E89FF&polygonFillColor=%232E8E8914&width=278&height=246&longitude=-0.01774911866484036&latitude=51.56659047694069&mapPolygon=couyHbKcCzEoAHyChFkI%7DKy%40oCuBxE%5B%5DUkAj%40UVo%40%60%40ZRcAiEsDBM%3FC%7BEmBJ%7C%40wIn%5Et%40nDR%5Bh%40h%40Li%40rBpHkDtCwDeFf%40_BNoFgGiKYG%60AhDOl%40e%40b%40mBsG%7DAWwA_ECm%40eBmD%3FCgAy%40w%40qBQPcFmOmCoGR%7B%40A%3F%7BR%7CYiLkTkAzBkB%3FXfABhBYt%40_%40NaAOh%40%60C%7CDnJzCnIFn%40%3FBXRfEjLBJxArRj%40xBLb%40ZGLNFfA%7C%40m%40fAjFe%40Z%3F%40n%40hDl%40%5Dd%40hBVVLIfAnCr%40_%40SaAfAhAg%40p%40Z%60B%60%40d%40CtAa%40dABf%40NhAz%40tBXbAb%40%40HpBn%40j%40v%40tG%40%3FPK%5ClArBfK%3FB%7CCcCNlANMJ%5E%3Fv%40z%40hDd%40Mj%40n%40o%40j%40Vl%40Cv%40%5CZL%7E%40ID%3F%40xA%7EF%40%3Fb%40VF%60%40b%40DSbAjAv%40%7C%40xGfEnPgBzB%60AlCyIhFiHxMgFvCoBh%40qCdFQnAgAfBCFlGfCtBlAR%5EbEbQl%40%7CBtEtRb%40nD%40AjKsY%40A%7CZgLfKyH%7BFwUfP%5C%5EiAn%40%7DDa%40qFwA%7BFYoCYh%40cAgAvGoFe%40u%40vDcQlC%7DD%7C%40w%40nGiBDkCrLa%5CrEmA%5Ba%40HCiH_KvHsRcBcCpH%7DLiDuFuC%7BBaDiCwFaH%7DEyIiDpGiBeDfA%7BDqF%7DFwA_CyBH&signature=AdUapPsMk0WBENMjLCbyqr0muDI=',
#   'mapViewUrl': 'https://www.rightmove.co.uk/house-prices/search.html?showMapView=showMapView&housePricesMap=Map+View&locationIdentifier=OUTCODE%5E745&propertyType=0'},
#  'searchLocation': {'displayName': 'E10',
#   'searchName': 'e10',
#   'locationType': 'OUTCODE',
#   'locationId': '745'},
#  'searchParameters': {},
#  'searchParameterDefaults': {'radius': '0.0',
#   'soldIn': '30',
#   'propertyType': 'ANY',
#   'propertyCategory': 'ANY',
#   'tenure': 'ANY',
#   'sortBy': 'DATE_SOLD'},
#  'pagination': {'current': 1, 'first': 1, 'last': 40, 'total': 7979},
#  'leadValuationModel': {'agents': [{'customerId': 17613,
#     'name': 'Leytonstone',
#     'displayAddress': '49/50 Church Lane,\r\nLondon,\r\nE11 1HE',
#     'logoUrl': 'https://media.rightmove.co.uk/brand/brand_logo_5437_0012.jpeg',
#     'tradingName': 'haart'},
#    {'customerId': 44250,
#     'name': 'London',
#     'displayAddress': 'London',
#     'logoUrl': 'https://media.rightmove.co.uk/company/clogo_4546_0002.jpeg',
#     'tradingName': 'Completion Sales & Lettings Ltd'},
#    {'customerId': 11554478,
#     'name': 'Walthamstow',
#     'displayAddress': '262 \r\nHoe Street\r\nLondon\r\nE17 3AX ',
#     'logoUrl': 'https://media.rightmove.co.uk/company/clogo_37211_0000.jpeg',
#     'tradingName': 'Sincere Property Services'},
#    {'customerId': 8089094,
#     'name': 'London',
#     'displayAddress': '320 High Road Leyton,\r\nLondon,\r\nE10 5PW',
#     'logoUrl': 'https://media.rightmove.co.uk/72k/71060/branch_logo_71060_0000.png',
#     'tradingName': '1 Click Homes Ltd'},
#    {'customerId': 7032256,
#     'name': 'Leyton',
#     'displayAddress': '254-256 High Road, Leyton, London, E10 5PW ',
#     'logoUrl': 'https://media.rightmove.co.uk/brand/brand_logo_82100_0000.png',
#     'tradingName': 'Outlook '},
#    {'customerId': 39354,
#     'name': 'Leytonstone',
#     'displayAddress': '658 \r\nHigh Road Leytonstone\r\nLondon\r\nE11 3AA ',
#     'logoUrl': 'https://media.rightmove.co.uk/brand/brand_logo_71570_0002.jpeg',
#     'tradingName': 'Bairstow Eves'}],
#   'postcode': {'outcode': 'E10', 'incode': None, 'outcodeId': 745}},
#  'disclaimer': {'showLandReg': True,
#   'showRos': False,
#   'loadDates': {'landReg': {'earliestTransaction': '1 January 1995',
#     'mostRecentTransaction': '30 December 2021',
#     'lastLoadDate': '10 February 2022'},
#    'ros': {'earliestTransaction': '18 October 1996',
#     'mostRecentTransaction': '31 December 2021',
#     'lastLoadDate': '10 February 2022'}}},
#  'mortgageWidgetModel': {'currentAverage': '£519,239',
#   'percentageChange': '11%',
#   'isIncrease': True}}

# %% [markdown]
# I was able to extract a dictionary from the javascript file using nodejs.

# %%
dict = big_file['results']['properties']
dict
# Out:
# [{'address': '11, Whitney Road, London, Greater London E10 7HG',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/66k/65394/109597502/65394_whitneyrd_IMG_00_0000_max_135x100.jpeg',
#    'count': 71},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£720,050',
#     'dateSold': '17 Dec 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£445,000',
#     'dateSold': '12 Aug 2015',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57167, 'lng': -0.01677},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109597502&sale=14270152&country=england'},
#  {'address': '82, Manor Road, Leyton, London, Greater London E10 7HN',
#   'propertyType': 'Terraced',
#   'bedrooms': 4,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/71k/70202/113322182/70202_102565007736_IMG_00_0000_max_135x100.jpeg',
#    'count': 13},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£643,756',
#     'dateSold': '9 Dec 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£355,000',
#     'dateSold': '7 Sep 2007',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£220,000',
#     'dateSold': '23 Mar 2006',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57082, 'lng': -0.01955},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=113322182&sale=14270155&country=england'},
#  {'address': '118, Newport Road, London, Greater London E10 6PG',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/33k/32706/111706949/32706_S76549_IMG_00_0000_max_135x100.jpeg',
#    'count': 11},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£504,000',
#     'dateSold': '29 Nov 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£400,000',
#     'dateSold': '7 Apr 2017',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56547, 'lng': -0.00145},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=111706949&sale=14270110&country=england'},
#  {'address': '8, Holden House, 616, High Road Leyton, London, Greater London E10 6EZ',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£130,000',
#     'dateSold': '26 Nov 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56901, 'lng': -0.00823},
#   'detailUrl': ''},
#  {'address': '3, Buckingham Road, London, Greater London E10 5NG',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/7k/6944/119899781/6944_2766_ALEN_IMG_00_0000_max_135x100.jpeg',
#    'count': 18},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£714,000',
#     'dateSold': '18 Nov 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£587,500',
#     'dateSold': '1 Jul 2014',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£294,950',
#     'dateSold': '11 Aug 2006',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£215,000',
#     'dateSold': '26 Sep 2003',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£134,995',
#     'dateSold': '10 Dec 1999',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56015, 'lng': -0.01063},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=119899781&sale=14270071&country=england'},
#  {'address': '55, Francis Road, London, Greater London E10 6PN',
#   'propertyType': 'Flat',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/77k/76750/47818463/76750_3bedff_IMG_00_0000_max_135x100.jpg',
#    'count': 4},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£540,000',
#     'dateSold': '15 Nov 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£440,000',
#     'dateSold': '5 Aug 2016',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56082, 'lng': -0.00252},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=47818463&sale=14270116&country=england'},
#  {'address': '88, Chesterfield Road, London, Greater London E10 6EN',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/12k/11536/79237872/11536_0172_HRT017209345_IMG_03_0002_max_135x100.jpeg',
#    'count': 22},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£630,000',
#     'dateSold': '12 Nov 2021',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57469, 'lng': -0.00423},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=79237872&sale=14270095&country=england'},
#  {'address': '6, Albert Road, Leyton, London, Greater London E10 6NX',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/115k/114391/90155578/114391_30514277_IMG_00_0000_max_135x100.jpeg',
#    'count': 20},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£434,500',
#     'dateSold': '5 Nov 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£225,000',
#     'dateSold': '19 Feb 2008',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£173,000',
#     'dateSold': '21 Sep 2007',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56418, 'lng': -0.00454},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=90155578&sale=13908223&country=england'},
#  {'address': '29, Colchester Road, Leyton, London, Greater London E10 6HB',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/7k/6944/66592116/6944_2574_IMG_01_0000_max_135x100.jpg',
#    'count': 14},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£740,000',
#     'dateSold': '29 Oct 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£560,500',
#     'dateSold': '11 Nov 2019',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57274, 'lng': -0.00561},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=66592116&sale=13908196&country=england'},
#  {'address': '64, Farmer Road, London, Greater London E10 5DH',
#   'propertyType': 'Terraced',
#   'bedrooms': 4,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/120k/119695/110642300/119695_30819352_IMG_00_0000_max_135x100.jpeg',
#    'count': 14},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£615,000',
#     'dateSold': '26 Oct 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£63,000',
#     'dateSold': '25 Jul 1997',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.5695, 'lng': -0.0108},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=110642300&sale=13908133&country=england'},
#  {'address': '3, East Point, 90, Church Road, Leyton, London, Greater London E10 5JP',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£322,500',
#     'dateSold': '25 Oct 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56345, 'lng': -0.01453},
#   'detailUrl': ''},
#  {'address': '19, Perth Road, London, Greater London E10 7PA',
#   'propertyType': 'Terraced',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/1k/568/77444976/568_LEY210021_IMG_15_0003_max_135x100.jpeg',
#    'count': 15},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£410,000',
#     'dateSold': '22 Oct 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.5668, 'lng': -0.0317},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=77444976&sale=14270170&country=england'},
#  {'address': '189, Dawlish Road, London, Greater London E10 6QN',
#   'propertyType': 'Flat',
#   'bedrooms': 1,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/57k/56158/109313330/56158_LEY210074_IMG_00_0000_max_135x100.jpeg',
#    'count': 12},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£400,000',
#     'dateSold': '22 Oct 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£351,500',
#     'dateSold': '15 Sep 2017',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£49,995',
#     'dateSold': '21 Aug 1997',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56213, 'lng': -0.00579},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109313330&sale=13908238&country=england'},
#  {'address': '150, Essex Road, Leyton, London, Greater London E10 6BS',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£371,000',
#     'dateSold': '18 Oct 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£368,000',
#     'dateSold': '4 Nov 2016',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£211,500',
#     'dateSold': '12 Jul 2007',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£55,000',
#     'dateSold': '17 Apr 1998',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£50,000',
#     'dateSold': '6 Sep 1996',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£28,000',
#     'dateSold': '28 May 1996',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£42,000',
#     'dateSold': '18 May 1995',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57722, 'lng': -0.00455},
#   'detailUrl': ''},
#  {'address': '126, St Marys Road, London, Greater London E10 5RF',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/33k/32706/109461365/32706_S72674_IMG_00_0000_max_135x100.jpeg',
#    'count': 13},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£690,000',
#     'dateSold': '15 Oct 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£600,000',
#     'dateSold': '20 Dec 2018',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£215,000',
#     'dateSold': '5 Mar 2007',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.5615, 'lng': -0.00552},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109461365&sale=13908151&country=england'},
#  {'address': '43, Nottingham Road, London, Greater London E10 6BP',
#   'propertyType': 'Semi-Detached',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/115k/114391/107499713/114391_30660773_IMG_00_0000_max_135x100.jpeg',
#    'count': 30},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£756,750',
#     'dateSold': '15 Oct 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£500,000',
#     'dateSold': '8 Aug 2014',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57606, 'lng': -0.00546},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=107499713&sale=13908175&country=england'},
#  {'address': '110, Murchison Road, London, Greater London E10 6LX',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/7k/6944/108825917/6944_3112_ALEN_IMG_00_0000_max_135x100.jpeg',
#    'count': 13},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£449,400',
#     'dateSold': '12 Oct 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£196,000',
#     'dateSold': '21 Feb 2013',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£165,000',
#     'dateSold': '4 Nov 2004',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£91,000',
#     'dateSold': '26 May 2000',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56491, 'lng': -0.00538},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=108825917&sale=13908211&country=england'},
#  {'address': '83, Newport Road, London, Greater London E10 6PH',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/120k/119695/109218089/119695_30745758_IMG_00_0000_max_135x100.jpeg',
#    'count': 15},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£480,000',
#     'dateSold': '1 Oct 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£475,000',
#     'dateSold': '14 Sep 2020',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£460,102',
#     'dateSold': '25 Jul 2016',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£175,000',
#     'dateSold': '15 Aug 2012',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56407, 'lng': -0.00368},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=109218089&sale=13908229&country=england'},
#  {'address': '67, Kettlebaston Road, London, Greater London E10 7PE',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/215k/214757/105763619/214757_30583874_IMG_00_0000_max_135x100.jpeg',
#    'count': 12},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£360,000',
#     'dateSold': '30 Sep 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£124,995',
#     'dateSold': '19 Sep 2002',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£58,995',
#     'dateSold': '27 May 1999',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£43,000',
#     'dateSold': '28 Feb 1995',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56705, 'lng': -0.03097},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=105763619&sale=13908298&country=england'},
#  {'address': '42, Wilmot Road, London, Greater London E10 5LU',
#   'propertyType': 'Terraced',
#   'bedrooms': 4,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/1k/568/108751715/568_LEY210138_IMG_15_0000_max_135x100.png',
#    'count': 15},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£700,000',
#     'dateSold': '30 Sep 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£249,999',
#     'dateSold': '26 Nov 2010',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£223,000',
#     'dateSold': '4 May 2005',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£184,000',
#     'dateSold': '25 Feb 2004',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£86,000',
#     'dateSold': '31 Jul 1999',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56263, 'lng': -0.01384},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=108751715&sale=13908142&country=england'},
#  {'address': '17, Essex Road, Leyton, London, Greater London E10 6HP',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/57k/56158/108584150/56158_LEY210039_IMG_00_0000_max_135x100.jpeg',
#    'count': 14},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£850,000',
#     'dateSold': '30 Sep 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£600,000',
#     'dateSold': '25 Jan 2016',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57365, 'lng': -0.00124},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=108584150&sale=13908199&country=england'},
#  {'address': '7, Perth Road, London, Greater London E10 7PA',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/36k/35033/107979368/35033_529018747_IMG_00_0000_max_135x100.jpeg',
#    'count': 17},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£420,000',
#     'dateSold': '29 Sep 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£275,000',
#     'dateSold': '19 Sep 2014',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.5668, 'lng': -0.0317},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=107979368&sale=14270167&country=england'},
#  {'address': '17, Huxley Road, London, Greater London E10 5QT',
#   'propertyType': 'Flat',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/203k/202958/106497410/202958_1173901-1_IMG_00_0000_max_135x100.jpeg',
#    'count': 15},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£485,000',
#     'dateSold': '29 Sep 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£226,500',
#     'dateSold': '25 Apr 2008',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56083, 'lng': -0.00844},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=106497410&sale=13631158&country=england'},
#  {'address': '27, Shortlands Road, London, Greater London E10 7AH',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/115k/114391/106280684/114391_30613989_IMG_00_0001_max_135x100.jpeg',
#    'count': 23},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£646,800',
#     'dateSold': '29 Sep 2021',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£510,000',
#     'dateSold': '31 May 2018',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57237, 'lng': -0.01544},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=106280684&sale=13631245&country=england'},
#  {'address': '48, Perth Road, London, Greater London E10 7PB',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/152k/151079/90505420/151079_1157966-1_IMG_00_0000_max_135x100.jpeg',
#    'count': 19},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£410,000',
#     'dateSold': '29 Sep 2021',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£54,000',
#     'dateSold': '28 Sep 1998',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56617, 'lng': -0.03173},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=90505420&sale=13908295&country=england'}]

# %% [markdown]
# Time to scrape the rest of the pages!

# %%
list_of_dicts = []

for n in range(1,40):
    scrape_url = 'https://www.rightmove.co.uk/house-prices/e10.html?page={}'.format(n)
    res = requests.get(scrape_url)

    soup = bs4.BeautifulSoup(res.text,'lxml')
    s = soup.select('script')
    s = s[1]
    js = 'window = {};\n'+s.text.strip()+';\nprocess.stdout.write(JSON.stringify(window.__PRELOADED_STATE__));'
    with open('temp.js','w') as f:
        f.write(js)
    window_init_state = check_output(['node','temp.js'])
    big_file = json.loads(window_init_state.decode("utf-8"))
    list_of_dicts.append(big_file['results']['properties'])

# %%
len(list_of_dicts)
# Out:
# 39

# %%
list_of_dicts[38]
# Out:
# [{'address': '4, Manor Road, Leyton, London, Greater London E10 7AL',
#   'propertyType': 'Semi-Detached',
#   'bedrooms': 5,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/33k/32706/66821818/32706_S41300_IMG_07_0000_max_135x100.jpg',
#    'count': 21},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£830,000',
#     'dateSold': '23 Jul 2019',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£103,500',
#     'dateSold': '30 Jan 1995',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56845, 'lng': -0.01792},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=66821818&sale=10188928&country=england'},
#  {'address': '13, Alexandra Road, Leyton, London, Greater London E10 5QQ',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/7k/6944/51728841/6944_2158_IMG_13_0001_max_135x100.jpg',
#    'count': 12},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£242,500',
#     'dateSold': '23 Jul 2019',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£204,000',
#     'dateSold': '20 Dec 2002',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.55775, 'lng': -0.00728},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=51728841&sale=56349764&country=england'},
#  {'address': '75, Nottingham Road, London, Greater London E10 6EP',
#   'propertyType': 'Terraced',
#   'bedrooms': 1,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/64k/63470/16247997/63470_NottinghamRoad_IMG_00_0000_max_135x100.jpg',
#    'count': 3},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£560,000',
#     'dateSold': '19 Jul 2019',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.5771, 'lng': -0.00268},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=16247997&sale=10188895&country=england'},
#  {'address': '68a, Dawlish Road, London, Greater London E10 6QD',
#   'propertyType': 'Flat',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/57k/56158/64411366/56158_26719975_IMG_11_0000_max_135x100.jpg',
#    'count': 10},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£390,000',
#     'dateSold': '18 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£193,000',
#     'dateSold': '11 Jun 2007',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£129,995',
#     'dateSold': '19 Nov 2004',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56471, 'lng': -0.00914},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=64411366&sale=90815970&country=england'},
#  {'address': '19, Griggs Road, London, Greater London E10 6ET',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/115k/114391/68470396/114391_28347209_IMG_01_0000_max_135x100.jpg',
#    'count': 20},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£488,000',
#     'dateSold': '17 Jul 2019',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£270,000',
#     'dateSold': '22 Feb 2013',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57524, 'lng': -0.00463},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=68470396&sale=10466482&country=england'},
#  {'address': '61b, Lyndhurst Drive, London, Greater London E10 6JB',
#   'propertyType': 'Flat',
#   'bedrooms': 1,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/11k/10145/77527445/10145_008139_IMG_11_0000_max_135x100.JPG',
#    'count': 13},
#   'hasFloorPlan': True,
#   'transactions': [{'displayPrice': '£235,000',
#     'dateSold': '17 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.5719, 'lng': -0.00391},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=77527445&sale=90602145&country=england'},
#  {'address': '97, Morley Road, London, Greater London E10 6LH',
#   'propertyType': 'Terraced',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£435,000',
#     'dateSold': '16 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56714, 'lng': -0.00441},
#   'detailUrl': ''},
#  {'address': '21, Dagenham Road, London, Greater London E10 7LH',
#   'propertyType': 'Terraced',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£199,995',
#     'dateSold': '15 Jul 2019',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£199,995',
#     'dateSold': '6 Oct 2004',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£47,000',
#     'dateSold': '28 Jun 1996',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56888, 'lng': -0.02714},
#   'detailUrl': ''},
#  {'address': '8b, Manor Road, Leyton, London, Greater London E10 7AL',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£372,500',
#     'dateSold': '12 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£350,000',
#     'dateSold': '29 Apr 2016',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£47,995',
#     'dateSold': '4 Jul 1997',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£34,000',
#     'dateSold': '22 Apr 1997',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56845, 'lng': -0.01792},
#   'detailUrl': ''},
#  {'address': '8, Brennan House, 608, High Road Leyton, London, Greater London E10 6RN',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£430,000',
#     'dateSold': '12 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£363,995',
#     'dateSold': '25 Aug 2016',
#     'tenure': 'Leasehold',
#     'newBuild': True}],
#   'location': {'lat': 51.56874, 'lng': -0.00824},
#   'detailUrl': ''},
#  {'address': '43, St Georges Road, Leyton, London, Greater London E10 5RQ',
#   'propertyType': 'Terraced',
#   'bedrooms': 2,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£300,000',
#     'dateSold': '12 Jul 2019',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.5603, 'lng': -0.00413},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=7952623&sale=10188880&country=england'},
#  {'address': 'Flat 17, Plaza Heights, 12, Maud Road, London, Greater London E10 5QS',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£387,500',
#     'dateSold': '12 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£380,000',
#     'dateSold': '6 Jul 2016',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£220,000',
#     'dateSold': '29 Sep 2005',
#     'tenure': 'Leasehold',
#     'newBuild': True}],
#   'location': {'lat': 51.55676, 'lng': -0.00703},
#   'detailUrl': ''},
#  {'address': '8, Primrose Road, London, Greater London E10 5ED',
#   'propertyType': 'Terraced',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/45k/44679/55547510/44679_0006211015_IMG_00_0000_max_135x100.png',
#    'count': 1},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£475,000',
#     'dateSold': '12 Jul 2019',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£425,000',
#     'dateSold': '12 Feb 2016',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£150,000',
#     'dateSold': '4 Aug 2006',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£77,000',
#     'dateSold': '29 Feb 2000',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.566, 'lng': -0.01629},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=55547510&sale=10188853&country=england'},
#  {'address': '116, Murchison Road, London, Greater London E10 6LX',
#   'propertyType': 'Flat',
#   'bedrooms': 3,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/63k/62824/28963147/62824_murchisonroadleytone10_IMG_00_0000_max_135x100.jpg',
#    'count': 2},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£390,000',
#     'dateSold': '8 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£166,000',
#     'dateSold': '20 Feb 2006',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£43,000',
#     'dateSold': '26 Apr 1996',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56491, 'lng': -0.00538},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=28963147&sale=56349788&country=england'},
#  {'address': '31, Lawton Road, London, Greater London E10 6RR',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/66k/65060/68358094/65060_LMP2384_IMG_61_0000_max_135x100.jpg',
#    'count': 11},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£365,000',
#     'dateSold': '5 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56641, 'lng': -0.00892},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=68358094&sale=11247901&country=england'},
#  {'address': 'Apartment 34, Rookery Court, 80, Ruckholt Road, London, Greater London E10 5FA',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£465,000',
#     'dateSold': '5 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£467,500',
#     'dateSold': '28 Oct 2016',
#     'tenure': 'Leasehold',
#     'newBuild': True}],
#   'location': {'lat': 51.55756, 'lng': -0.01176},
#   'detailUrl': ''},
#  {'address': '63, Crawley Road, London, Greater London E10 6RJ',
#   'propertyType': 'Flat',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/63k/62824/35302714/62824_54545848_IMG_02_0000_max_135x100.jpg',
#    'count': 1},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£380,000',
#     'dateSold': '4 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£292,000',
#     'dateSold': '10 Feb 2014',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£234,000',
#     'dateSold': '30 Nov 2007',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£162,000',
#     'dateSold': '6 Jun 2007',
#     'tenure': 'Freehold',
#     'newBuild': False},
#    {'displayPrice': '£129,995',
#     'dateSold': '26 Jan 2004',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£74,000',
#     'dateSold': '23 May 2001',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56664, 'lng': -0.01194},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=35302714&sale=10188925&country=england'},
#  {'address': '34a, Radlix Road, London, Greater London E10 7BD',
#   'propertyType': 'Flat',
#   'bedrooms': 1,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/97k/96668/76607398/96668_69503704012020_IMG_04_0000_max_135x100.jpg',
#    'count': 10},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£188,000',
#     'dateSold': '4 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£71,000',
#     'dateSold': '2 Nov 2001',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56687, 'lng': -0.02001},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=76607398&sale=10188934&country=england'},
#  {'address': '5, Lord Clyde Apartments, 175, Capworth Street, London, Greater London E10 5AR',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£285,000',
#     'dateSold': '2 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False},
#    {'displayPrice': '£172,000',
#     'dateSold': '12 Apr 2013',
#     'tenure': 'Leasehold',
#     'newBuild': True}],
#   'location': {'lat': 51.57058, 'lng': -0.01595},
#   'detailUrl': ''},
#  {'address': '676a, High Road Leyton, London, Greater London E10 6JP',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£228,000',
#     'dateSold': '2 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57126, 'lng': -0.00827},
#   'detailUrl': ''},
#  {'address': '11a, Fletcher Lane, London, Greater London E10 6JE',
#   'propertyType': 'Flat',
#   'bedrooms': 1,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/62k/61544/61664521/61544_4500281_IMG_01_0000_max_135x100.jpg',
#    'count': 11},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£300,000',
#     'dateSold': '1 Jul 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57042, 'lng': -0.00672},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=61664521&sale=10188898&country=england'},
#  {'address': '5, Frobisher Gardens, London, Greater London E10 7AY',
#   'propertyType': 'Terraced',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£408,000',
#     'dateSold': '28 Jun 2019',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.57387, 'lng': -0.01364},
#   'detailUrl': ''},
#  {'address': '78, Brunswick Road, London, Greater London E10 6RS',
#   'propertyType': 'Flat',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£385,000',
#     'dateSold': '28 Jun 2019',
#     'tenure': 'Leasehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56667, 'lng': -0.00804},
#   'detailUrl': ''},
#  {'address': '130, Manor Road, Leyton, London, Greater London E10 7HW',
#   'propertyType': 'Terraced',
#   'bedrooms': 2,
#   'images': {'imageUrl': 'https://media.rightmove.co.uk/dir/36k/35033/59222499/35033_528873774_IMG_01_0000_max_135x100.jpg',
#    'count': 25},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£450,000',
#     'dateSold': '28 Jun 2019',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.5711, 'lng': -0.02026},
#   'detailUrl': 'https://www.rightmove.co.uk/house-prices/detailMatching.html?prop=59222499&sale=10188952&country=england'},
#  {'address': '18, Murchison Road, London, Greater London E10 6NB',
#   'propertyType': 'Terraced',
#   'bedrooms': None,
#   'images': {'imageUrl': '/spw/images/placeholder/no-image.svg', 'count': 0},
#   'hasFloorPlan': False,
#   'transactions': [{'displayPrice': '£707,500',
#     'dateSold': '27 Jun 2019',
#     'tenure': 'Freehold',
#     'newBuild': False}],
#   'location': {'lat': 51.56263, 'lng': -0.00879},
#   'detailUrl': ''}]

# %%
import pandas as pd
import numpy as np

# %%
np.save('list_of_dicts.npy', list_of_dicts)

# %% [markdown]
# Time to create a dataframe from the extracted list of dictionaries.

# %%
list_of_df = []
for dict in list_of_dicts:
    x = pd.DataFrame(dict)
    list_of_df.append(x)

prop_df = pd.concat(list_of_df)

# %%
prop_df.head()
# Out:
#                                              address propertyType  bedrooms  \
# 0   11, Whitney Road, London, Greater London E10 7HG     Terraced       3.0
# 1  82, Manor Road, Leyton, London, Greater London...     Terraced       4.0
# 2  118, Newport Road, London, Greater London E10 6PG         Flat       2.0
# 3  8, Holden House, 616, High Road Leyton, London...         Flat       NaN
# 4  3, Buckingham Road, London, Greater London E10...     Terraced       3.0
#
#                                               images  hasFloorPlan  \
# 0  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 1  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 2  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
# 3  {'imageUrl': '/spw/images/placeholder/no-image...         False
# 4  {'imageUrl': 'https://media.rightmove.co.uk/di...          True
#
#                                         transactions  \
# 0  [{'displayPrice': '£720,050', 'dateSold': '17 ...
# 1  [{'displayPrice': '£643,756', 'dateSold': '9 D...
# 2  [{'displayPrice': '£504,000', 'dateSold': '29 ...
# 3  [{'displayPrice': '£130,000', 'dateSold': '26 ...
# 4  [{'displayPrice': '£714,000', 'dateSold': '18 ...
#
#                              location  \
# 0  {'lat': 51.57167, 'lng': -0.01677}
# 1  {'lat': 51.57082, 'lng': -0.01955}
# 2  {'lat': 51.56547, 'lng': -0.00145}
# 3  {'lat': 51.56901, 'lng': -0.00823}
# 4  {'lat': 51.56015, 'lng': -0.01063}
#
#                                            detailUrl
# 0  https://www.rightmove.co.uk/house-prices/detai...
# 1  https://www.rightmove.co.uk/house-prices/detai...
# 2  https://www.rightmove.co.uk/house-prices/detai...
# 3
# 4  https://www.rightmove.co.uk/house-prices/detai...

# %% [markdown]
# As you can see there is a need to further unpack some columns before I can conduct Exploratory Data Analysis. For example, 'transactions' needs to be further broken down to extract more features. Furthermore, 'transactions' can take lists and therefore takes multiple values for the same address.

# %%
prop_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 975 entries, 0 to 24
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   address       975 non-null    object
#  1   propertyType  975 non-null    object
#  2   bedrooms      586 non-null    float64
#  3   images        975 non-null    object
#  4   hasFloorPlan  975 non-null    bool
#  5   transactions  975 non-null    object
#  6   location      975 non-null    object
#  7   detailUrl     975 non-null    object
# dtypes: bool(1), float64(1), object(6)
# memory usage: 61.9+ KB
